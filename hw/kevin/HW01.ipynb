# %% [markdown]
# # Kevin Egedy
# ## EE 560 P: Electric Machines and Drives
# ## Homework 01
# ### Due 2 November, 2020
#
# Copyright &copy; 2019, University of Washington
#
# <hr>

# %% [markdown]
# #### Basic Equations DC Machines
#
# <hr>

# %% [markdown]
# **Armatur Circuit**
#
# $\begin{eqnarray}
# & v_a &=& R_a i_a + L_a \frac{di_a}{dt} + e_a \\[0.5em]
# & v_a &:& \text{armature voltage} \\
# & i_a &:& \text{armature current} \\
# & R_a &:& \text{armature winding resistance} \\
# & L_a &:& \text{armature winding inductance} \\
# & e_a &:& \text{back electro motive force (EMF)} \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Field Circuit**
#
# $\begin{eqnarray}
# & v_f &=& R_f i_f + L_f \frac{di_f}{dt} \\[0.5em]
# & v_f &:& \text{field voltage} \\
# & i_f &:& \text{field current} \\
# & R_f &:& \text{field winding resistance} \\
# & L_f &:& \text{field winding inductance} \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Back EMF**
#
# $\begin{eqnarray}
# & e_a &=& K_f i_f \omega = K_e \omega \\[0.5em]
# & K_f &:& \text{field constant (geometry dependent)} \\
# & i_f &:& \text{field current} \\
# & \omega &:& \text{rotor speed} \\
# & K_e &:& \text{back EMF constant (at a fixed field current), } & K_e = K_f i_f\\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Torque Equation**
#
# $\begin{eqnarray}
# & t_{em} &=& K_f i_f i_a = K_t i_a \\[0.5em]
# & t_{em} &:& \text{electromagnetic torque produced by motor} \\
# & K_f &:& \text{field constant (geometry dependent)} \\
# & i_f &:& \text{armature current} \\
# & i_a &:& \text{armature current} \\
# & K_t &:& \text{torque constant (at a fixed field current, )} & K_t = \phi_f = K_f i_f\\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Mechanical Equation**
#
# $\begin{eqnarray}
# & J \frac{d\omega}{dt} + b\omega + t_L &=& t_{em}\\[0.5em]
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & J &:& \text{total rotation inertia} \\
# & \omega &:& \text{rotor speed} \\
# & t_{em} &:& \text{electromagnetic torque produced by motor} \\
# & b &:& \text{viscous damping coeff} \\
# & t_L &:& \text{load torque} \\
# \end{eqnarray}$

# %% [markdown]
# **Steady State Operation with Constant Flux**
#
# $\begin{eqnarray}
# & i_f &=& I_F \\
# & i_a &=& I_a \\
# & \omega &=& \text{constant} \\
# & V_f &=& R_f I_f \\
# & V_a &=& R_a I_a + E_a \\
# & T_{em} &=& K_t I_a \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Speed-Torque Characteristics**
#
# Given:<br>
# $\begin{eqnarray}
# & e_a &=& E_a \\
# & v_a &=& V_a \\
# & \phi_f &=& \text{constant} \\
# & K_e = K_t &=& \text{constant} \\
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \omega_{NL} &=& \frac{E_a}{K_e} &=& \frac{V_a - I_a R_a}{K_e}\Bigg|_{I_a = t_{em}/K_t} &=& \frac{V_a}{K_e}-\frac{R_a}{K_e K_t}t_{em} & \text{[Speed rad/sec]} \\[0.5em]
# & t_{em} &=& K_t I_a &=& K_t \frac{V_a-E_a}{R_a} &=& \frac{K_t}{R_a}V_a - \frac{K_e K_t}{R_a}\omega_{NL} & \text{[Torque }N\cdot m\text{]} \\[0.5em]
# \end{eqnarray}$
#
# Motor Constant $K_m$  $[\frac{\text{Torque}}{\sqrt{\text{Watt}}}]$
#
# $\begin{eqnarray}
# & K_m^2 &=& \frac{K_e K_t}{R_a} &=& \frac{K_e K_t}{R_a}\frac{I_a^2}{I_a^2} &=& \frac{T_{em}^2}{P_{\text{LOSS}}} \\[0.5em]
# & K_m &=& \frac{T_{em}}{\sqrt{P_{\text{LOSS}}}}
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \text{slope} &=& \frac{-R_a}{K_e K_t} &=& \frac{-1}{K_m^2}
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Series Wound DC Motor**
#
# (Steady State)
#
# $\begin{eqnarray}
# & T_{SS}(\omega) &\propto& \frac{V_a^2}{\omega^2} \\
# & T_{SS}(\omega) &=& \frac{K_f V_a^2}{(R_a+R_f+K_f \omega)^2} \\[0.5em]
# & E_a &=& K_e \omega = I K_f \omega \\[0.5em]
# & V_{SS} &=& (R_a + R_f)I + E_a &=& (R_a + R_f)I + I K_f \omega \\[0.5em]
# & I &=& \frac{V_{SS}}{R_a + R_f + K_f \omega} \\[0.5em]
# & T_em &=& K_t I = K_f I^2 \\[0.5em]
# & &=& \frac{V_{SS}^2}{(R_a + R_f + K_f \omega)^2}
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Dynamics**
#
# Laplace: $\frac{d}{dt} \rightarrow p$ <br>
#
# $\begin{align}
#   \begin{array}{ll}
#   \text{Equation} & \text{Time Domain Representation} & \text{LaPlace Domain Representation} \\[0.5em]
#   \text{Armature} & v_a(t) = R_a i_a(t) + L_a \frac{di_a(t)}{dt} + e_a(t) & V_a(p) = R_a I_a(p) + L_a I_a(p)p  + E_a(p) \\[0.5em]
#   \text{Field} & v_f(t) = R_f i_f(t) + L_f \frac{di_f(t)}{dt} & V_f(p) = R_f I_f(p) + L_f  I_f(p)p \\[0.5em]
#   \text{Mechanical} & J\frac{d\omega(t)}{dt} + b\omega(t) + t_L(t) = t_{em}(t) & J\Omega(p)p + b\Omega(p) + T_L(p) = T_{em}(p)
#   \end{array}
# \end{align}$

# %% [markdown]
# **Dynamic Model**
#
# <img src="images/BlockDiagramDCMotor.png" width="500"/>

# %% [markdown]
# $\begin{eqnarray}
# & \Omega &=& \frac{K_t}{JL_a  p^2 + (L_a b + JR_a)p + K_e K_t + bR_a}V_a - \frac{L_a p + R_a}{JL_a p^2 + (L_a b + JR_a)p + K_e K_t + bR_a}T_L \\[0.5em]
# & \frac{\Omega}{V_a} &=& \frac{K_t}{JL_a  p^2 + (L_a b + JR_a)p + K_e K_t + bR_a} \text{ [speed/voltage]}\\[0.5em]
# & \frac{\Omega}{T_L} &=& \frac{L_a p + R_a}{JL_a p^2 + (L_a b + JR_a)p + K_e K_t + bR_a} \text{ [speed/load]}\\[0.5em]
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \text{Let} \\
# && K &=& K_e = K_t \\
# && b &=& 0 &\text{ [viscous damping]} \\
# & \text{Then}
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \frac{\Omega}{V_a} &=& \frac{\frac{K}{JR_a}}{p^2+\frac{R_a}{L_a}p+ \frac{K^2}{JL_a}} \\[0.5em]
# & &=& \frac{\frac{K}{JR_a}}{p^2+\frac{1}{\tau_e}p+ \frac{1}{\tau_m \tau_e}} \text{ [speed/voltage]} \\[0.5em]
# & \tau_e &=& \frac{L_a}{R_a} \text{ electrical time constant} \\[0.5em]
# & \tau_m &=& \frac{JR_a}{K^2} \text{ equivalent electromechanical time constant if electrical transients are very fast}
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Continuing**
#
# $\begin{eqnarray}
# & \text{If} \\
# && L_a &=& 0 \text{ [armature inductance]} \\
# & \text{Then}
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \frac{\Omega}{V_a} &=& \frac{\frac{K}{JR_a}}{p+\frac{K^2}{JR_a}}  \\[0.5em]
# & &=& \frac{\frac{1}{K}\frac{R_a}{L_a}\frac{K^2}{JR_a}}{p^2+\frac{1}{\tau_e}p+ \frac{1}{\tau_m \tau_e}} \\[0.5em]
# & &=& \frac{\frac{1}{K \tau_m \tau_e}}{p^2+\frac{1}{\tau_e}p+ \frac{1}{\tau_m \tau_e}} \text{ [speed/voltage]} \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Roots**
#
# $\begin{eqnarray}
# & p &=& -\frac{1}{2\tau_e} \pm \sqrt{\frac{1}{4\tau_e^2}-\frac{1}{\tau_e \tau_m}} \\[0.5em]
# & &=& -\frac{1}{2\tau_e} \pm \frac{1}{\tau_e} \sqrt{\frac{1}{4}-\frac{\tau_e}{\tau_m}} \\[0.5em]
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \text{real roots:} && \frac{\tau_e}{\tau_m} \leq \frac{1}{4} &\rightarrow& \tau_e \leq \frac{1}{4}\tau_m \\[0.5em]
# & \text{complex roots:} && \frac{\tau_e}{\tau_m} \geq \frac{1}{4} &\rightarrow& \tau_e \geq \frac{1}{4}\tau_m \\[0.5em]
# \end{eqnarray}$
#
# <hr>

# %%
# Imports
import sympy as sp
import numpy as np
import pandas as pd
import control
from scipy import signal
from scipy import linalg
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option("display.max_rows", 101)
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline

# Constants
Vf = 360
radsec2rpm = 30/np.pi

# %% [markdown]
# #### 1W Motor

# %%
# 1W Motor
Va1 = 170
If1 = 0.52
Rf1 = Vf/If1
Lf1 = 0.15
Ra1 = 5.59
La1 = 15.5e-3
wn1 = 1300*np.pi/30
Tr1 = 7.0
J1= 3.2e-3
b1 = 1e-5
Ke1 = Va1/wn1
Kf1 = Ke1/If1
Kt1 = Kf1*If1
K = Ke1

# %%
# Roots Scypi
# Include damping and armature inductance!

num1 = [K]
den1 = [J1*La1, La1*b1+J1*Ra1, K**2+b1*Ra1]
tf1 = signal.TransferFunction(num1, den1)
tf1.poles
# Out:
# array([-213.13292354, -147.51536275])

# %%
# Step: Scypi
fig,ax = plt.subplots(1)

T = np.linspace(0,0.25,1000)
t1, y1 = signal.step2(tf1,T=T)
plt.plot(t1, y1)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Speed')
ax.set_title(r'$\frac{\Omega}{V_a}$ Step Response: 1W Motor')
plt.grid(True)
plt.show();

# %% [markdown]
# #### 90.8 W Motor

# %%
# 90.8W Motor
Va91 = 460
If91 = 3.5
Rf91 = Vf/If91
Lf91 = 0.015
Ra91 = 0.09
La91 = 1.0e-3
wn91 = 3000*np.pi/30
Tr91 = 289
J91= 0.2452
b91 = 1e-4
Ke91 = Va91/wn91
Kf91 = Ke91/If91
Kt91 = Kf91*If91
K = Ke91

# %%
# Roots Scypi
# Include damping and armature inductance!

num91 = [K]
den91 = [J91*La91, La91*b91+J91*Ra91, K**2+b91*Ra91]
tf91 = signal.TransferFunction(num91, den91)
tf91.poles
# Out:
# array([-45.00020392+81.96781353j, -45.00020392-81.96781353j])

# %%
# Step: Scypi
fig,ax = plt.subplots(1)

T = np.linspace(0,0.25,1000)
t91, y91 = signal.step2(tf91,T=T)
plt.plot(t91, y91)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Speed')
ax.set_title(r'$\frac{\Omega}{V_a}$ Step Response: 1W Motor')
plt.grid(True)
plt.show();

# %%
# Plot Results in 1 Graph
fig,axs = plt.subplots(2,2, figsize=(12,12))

axs[0, 0].scatter(np.real(tf1.poles),np.imag(tf1.poles),marker='x')
axs[0, 0].set_xlim(-250, 0)
axs[0, 0].set_ylim(50, -50)
axs[0, 0].set_title('1W Motor Eigenvalues')
axs[0, 0].set(xlabel='$\operatorname{Re}(z)$', ylabel='$\operatorname{Im}(z)$')

axs[0, 1].plot(t1, y1)
axs[0, 1].set_title('1W Motor Step Response')
axs[0, 1].set(xlabel='Time(s)', ylabel=r'Speed ($\frac{rad}{V \cdot s}$)')

axs[1, 0].scatter(np.real(tf91.poles),np.imag(tf91.poles),marker='x',color='tab:orange')
axs[1, 0].set_xlim(-50, 0)
axs[1, 0].set_ylim(100, -100)
axs[1, 0].set_title('90.8W Motor Eigenvalues')
axs[1, 0].set(xlabel='$\operatorname{Re}(z)$', ylabel='$\operatorname{Im}(z)$')

axs[1, 1].plot(t91, y91,color='tab:orange')
axs[1, 1].set_title('90.8W Motor Step Response')
axs[1, 1].set(xlabel='Time(s)', ylabel=r'Speed ($\frac{rad}{V \cdot s}$)')

for ax in axs.flat:
    ax.grid(True)
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
#    ax.label_outer()

plt.show();

# %% [markdown]
# #### Speed Torque

# %% [markdown]
# Given:<br>
# $\begin{eqnarray}
# & e_a &=& E_a \\
# & v_a &=& V_a \\
# & \phi_f &=& \text{constant} \\
# & K_e = K_t &=& \text{constant} \\
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \omega_{NL} &=& \frac{E_a}{K_e} &=& \frac{V_a - I_a R_a}{K_e}\Bigg|_{I_a = t_{em}/K_t} &=& \frac{V_a}{K_e}-\frac{R_a}{K_e K_t}t_{em} & \text{[Speed rad/sec]} \\[0.5em]
# & t_{em} &=& K_t I_a &=& K_t \frac{V_a-E_a}{R_a} &=& \frac{K_t}{R_a}V_a - \frac{K_e K_t}{R_a}\omega_{NL} & \text{[Torque }N\cdot m\text{]} \\[0.5em]
# \end{eqnarray}$

# %%
# Find stall values
T = sp.symbols('T')
sol = sp.solve(sp.Matrix([(Va1/Ke1) - (Ra1/(Ke1*Kt1))*T]))
n1 = float(list(dict(sol).values())[0])
sol = sp.solve(sp.Matrix([(Va91/Ke91) - (Ra91/(Ke91*Kt91))*T]))
n91 = float(list(dict(sol).values())[0])

# Speed Torque Equations
speed_radsec1 = lambda T: (Va1/Ke1) - (Ra1/(Ke1*Kt1))*T
speed_radsec91 = lambda T: (Va91/Ke91) - (Ra91/(Ke91*Kt91))*T

# %%
y0 = speed_radsec1(0)*radsec2rpm
label0 = f"(0, {round(y0,2)})"
y1 = speed_radsec1(n1)*radsec2rpm
label1 = f"({round(n1,2)}, {abs(round(y1,2))})"
y2 = speed_radsec91(0)*radsec2rpm
label2 = f"(0, {round(y2,2)})"
y3 = speed_radsec91(n91)*radsec2rpm
label3 = f"({round(n91,2)}, {round(y3,2)})"

# %%
fig,axs = plt.subplots(2,1,figsize=(10,10))
T1 = np.linspace(0,n1,100)
T91 = np.linspace(0,n91,100)

axs[0].plot(T1,speed_radsec1(T1)*radsec2rpm)
axs[0].scatter(0,y0,label=label0,color='tab:blue')
axs[0].scatter(n1,y1,label=label1,color='tab:blue')
#axs[0, 0].set_xlim(-250, 0)
#axs[0, 0].set_ylim(50, -50)
axs[0].set_title('1W Motor Speed Torque')
axs[0].set(xlabel=r'Torque (N $\cdot$ m)', ylabel=r'Speed (rpm)')

axs[1].plot(T91,speed_radsec91(T91)*radsec2rpm,color='tab:orange')
axs[1].scatter(0,y2,label=label2,color='tab:orange')
axs[1].scatter(n91,y3,label=label3,color='tab:orange')
#axs[1].set_xlim(-50, 0)
#axs[1].set_ylim(100, -100)
axs[1].set_title('90.8W Motor Speed Torque')
axs[1].set(xlabel=r'Torque (N $\cdot$ m)', ylabel=r'Speed (rpm)')

for ax in axs.flat:
    ax.grid(True)
    ax.legend()
plt.show();

# %% [markdown]
# #### Simulation

# %%
loadcase1_small= pd.read_csv('data/data_loadcase1_small.csv',dtype=np.float64)
loadcase1_small= loadcase1_small[loadcase1_small['Time']<0.25]

loadcase1_large= pd.read_csv('data/data_loadcase1_large.csv',dtype=np.float64)
loadcase1_large= loadcase1_large[loadcase1_large['Time']<0.25]

loadcase2_small= pd.read_csv('data/data_loadcase2_small.csv',dtype=np.float64)
loadcase2_small= loadcase2_small[loadcase2_small['Time']<0.25]

loadcase2_large= pd.read_csv('data/data_loadcase2_large.csv',dtype=np.float64)
loadcase2_large= loadcase2_large[loadcase2_large['Time']<0.25]

# %%
loadcase1_large.head()
# Out:
#        Time  DC Machine1:Armature current  DC Machine1:Field current  \
# 0  0.000000                      0.000000                        3.5
# 1  0.000001                      0.459979                        3.5
# 2  0.000009                      4.138323                        3.5
# 3  0.000073                     33.469687                        3.5
# 4  0.000204                     93.019071                        3.5
#
#    DC Machine1:Rotational speed  DC Machine1:Electrical torque
# 0                      0.000000                       0.000000
# 1                     -0.000003                       0.673513
# 2                      0.000075                       6.059439
# 3                      0.007005                      49.007168
# 4                      0.056026                     136.200893

# %%
# Plot Results in 1 Graph
fig,axs = plt.subplots(3,2, figsize=(12,16))

axs[0, 0].plot(loadcase1_small['Time'],loadcase1_small['DC Machine:Armature current'],label='0.1 Nm')
axs[0, 0].plot(loadcase2_small['Time'],loadcase2_small['DC Machine:Armature current'],label='7.0 Nm')
axs[0, 0].set_title('1W Motor Armature Current (A)')
axs[0, 0].set(ylabel='Current (A)')

axs[0, 1].plot(loadcase1_large['Time'],loadcase1_large['DC Machine1:Armature current'],label='1.0 Nm')
axs[0, 1].plot(loadcase2_large['Time'],loadcase2_large['DC Machine1:Armature current'],label='300 Nm')
axs[0, 1].set_title('90.8W Motor Armature Current (A)')
axs[0, 1].set(ylabel='Current (A)')

axs[1, 0].plot(loadcase1_small['Time'],loadcase1_small['DC Machine:Rotational speed']*radsec2rpm,label='0.1 Nm')
axs[1, 0].plot(loadcase2_small['Time'],loadcase2_small['DC Machine:Rotational speed']*radsec2rpm,label='7.0 Nm')
axs[1, 0].set_title('1W Motor Speed $\omega$ (rpm)')
axs[1, 0].set(ylabel='Speed (rpm)')

axs[1, 1].plot(loadcase1_large['Time'],loadcase1_large['DC Machine1:Rotational speed']*radsec2rpm,label='1.0 Nm')
axs[1, 1].plot(loadcase2_large['Time'],loadcase2_large['DC Machine1:Rotational speed']*radsec2rpm,label='300 Nm')
axs[1, 1].set_title('90.8W Motor Speed $\omega$ (rpm)')
axs[1, 1].set(ylabel='Speed (rpm)')

axs[2, 0].plot(loadcase1_small['Time'],loadcase1_small['DC Machine:Electrical torque'],label='0.1 Nm')
axs[2, 0].plot(loadcase2_small['Time'],loadcase2_small['DC Machine:Electrical torque'],label='7.0 Nm')
axs[2, 0].set_title(r'1W Motor Electrical Torque (N $\cdot$ m)')
axs[2, 0].set(ylabel=r'Current (N $\cdot$ m)',xlabel='Time (s)')

axs[2, 1].plot(loadcase1_large['Time'],loadcase1_large['DC Machine1:Electrical torque'],label='1.0 Nm')
axs[2, 1].plot(loadcase2_large['Time'],loadcase2_large['DC Machine1:Electrical torque'],label='300 Nm')
axs[2, 1].set_title(r'90.8W Motor Electrical Torque (N $\cdot$ m)')
axs[2, 1].set(ylabel=r'Current (N $\cdot$ m)',xlabel='Time (s)')


for ax in axs.flat:
    ax.grid(True)
    ax.legend()

plt.show();

# %% [markdown]
# <hr>
#
# #### Testing

# %%
# 1W Motor
Va1 = 170
If1 = 0.52
Rf1 = Vf/If1
Lf1 = 0.15
Ra1 = 5.59
La1 = 15.5e-3
wn1 = 1300*np.pi/30
Tr1 = 7.0
J1= 3.2e-3
b1 = 1e-5
Ke1 = Va1/wn1
Kf1 = Ke1/If1
K = Ke1

# %%
# Roots: sympy
p = sp.symbols('p')
TauE = La1/Ra1
TauM = J1*Ra1
H = sp.Matrix([p**2 + p/TauE + 1/(TauE*TauM)])
sols = sp.solve(H)
for sol in sols:
    print(sol)
# Out:
# {p: -291.475370839336}
# {p: -69.1697904509870}

# %%
# Roots: scipy and sympy -> State Spaces
A,B,C,D = signal.tf2ss([1/(K*TauE*TauM)],[1,1/TauE,1/(TauE*TauM)])
A = sp.Matrix(A)
sols = A.eigenvals()
for sol in sols:
    print(complex(sol))
# Out:
# (-291.475370839336+0j)
# (-69.16979045098701+0j)

# %%
# Roots: Control
s = control.tf('s')
G = (1/(K*TauE*TauM))/(s**2 + s/TauE + 1/(TauE*TauM))

rlist,klist = control.root_locus(G)
rlist[0]
plt.show()
# Out:
# array([-291.47537084+0.j,  -69.16979045+0.j])

# %%
# Step: Control
fig,ax = plt.subplots(1)

response = control.step_response(G)
ax.plot(response[0],response[1])

ax.set_xlabel('Time (s)')
ax.set_ylabel('Speed')
ax.set_title(r'$\frac{\Omega}{V_a}$ Step Response: 1W Motor')
plt.grid(True)
plt.show();

# %%
# 90.8W Motor
Va91 = 460
If91 = 3.5
Rf91 = Vf/If91
Lf91 = 0.015
Ra91 = 0.09
La91 = 1.0e-3
wn91 = 3000*np.pi/30
Tr91 = 289
J91= 0.2452
b91 = 1e-4
Ke91 = Va91/wn91
Kf91 = Ke91/If91
Kt91 = Kf91*If91
K = Ke91

# %%
# Roots: Sympy
p = sp.symbols('p')
TauE = La91/Ra91
TauM = J91*Ra91
H = sp.Matrix([p**2 + p/TauE + 1/(TauE*TauM)])
sols = sp.solve(H)
for sol in sols:
    print(sol)
# Out:
# {p: -45.0 - 45.3133912411649*I}
# {p: -45.0 + 45.3133912411649*I}

# %%
# Roots: Control
s = control.tf('s')
G = (1/(K*TauE*TauM))/(s**2 + s/TauE + 1/(TauE*TauM))

rlist,klist = control.root_locus(G)
rlist[0]
plt.show()
# Out:
# array([-45.-45.31339124j, -45.+45.31339124j])

# %%
fig,ax = plt.subplots(1)

response = control.step_response(G)
ax.plot(response[0],response[1])

ax.set_xlabel('Time (s)')
ax.set_ylabel('Speed')
ax.set_title(r'$\frac{\Omega}{V_a}$ Step Response: 1W Motor')
plt.grid(True)
plt.show();

# %%
# References

# http://robertobucher.dti.supsi.ch/wp-content/uploads/2017/03/BookPythonForControl.pdf
# https://python-control.readthedocs.io/en/latest/generated/control.root_locus.html?highlight=root%20locus
# https://python-control.readthedocs.io/en/latest/generated/control.root_locus.html?highlight=root%20locus

# http://home.ku.edu.tr/~alperdogan/elec304/StateSpaceStability.pdf

# %%
# Sympy inverse_laplace_transform 
# DON'T USE

p,t = sp.symbols('p,t')
omega, zeta = sp.symbols('omega, zeta',real=True)
num = omega**2 
den = p**2 + 2*zeta*omega*p + omega**2
eqn = num/den
eqn
sol = sp.inverse_laplace_transform(eqn, p, t)
sp.simplify(sol)
# Out:
# omega**2/(omega**2 + 2*omega*p*zeta + p**2)
# omega*(I*exp(2*omega*t*cos(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1)))*sin(omega*t*sin(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1))) + exp(2*omega*t*cos(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1)))*cos(omega*t*sin(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1))) + I*sin(omega*t*sin(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1))) - cos(omega*t*sin(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1))))*exp(-omega*t*(zeta + cos(atan2(0, zeta**2 - 1)/2)*sqrt(Abs(zeta**2 - 1))))*Heaviside(t)/(2*sqrt(zeta**2 - 1))
