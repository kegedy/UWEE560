# %% [markdown]
# # Kevin Egedy
# ## EE 560 P: Electric Machines and Drives
# ## Homework 01
# ### Due 2 November, 2020
#
# Copyright &copy; 2019, University of Washington
#
# <hr>

# %% [markdown]
# #### Basic Equations DC Machines
#
# <hr>

# %% [markdown]
# **Armatur Circuit**
#
# $\begin{eqnarray}
# & v_a &=& R_a i_a + L_a \frac{di_a}{dt} + e_a \\[0.5em]
# & v_a &:& \text{armature voltage} \\
# & i_a &:& \text{armature current} \\
# & R_a &:& \text{armature winding resistance} \\
# & L_a &:& \text{armature winding inductance} \\
# & e_a &:& \text{back electro motive force (EMF)} \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Field Circuit**
#
# $\begin{eqnarray}
# & v_f &=& R_f i_f + L_f \frac{di_f}{dt} \\[0.5em]
# & v_f &:& \text{field voltage} \\
# & i_f &:& \text{field current} \\
# & R_f &:& \text{field winding resistance} \\
# & L_f &:& \text{field winding inductance} \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Back EMF**
#
# $\begin{eqnarray}
# & e_a &=& K_f i_f \omega = K_e \omega \\[0.5em]
# & K_f &:& \text{field constant (geometry dependent)} \\
# & i_f &:& \text{field current} \\
# & \omega &:& \text{rotor speed} \\
# & K_e &:& \text{back EMF constant (at a fixed field current), } & K_e = K_f i_f\\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Torque Equation**
#
# $\begin{eqnarray}
# & t_{em} &=& K_f i_f i_a = K_t i_a \\[0.5em]
# & t_{em} &:& \text{electromagnetic torque produced by motor} \\
# & K_f &:& \text{field constant (geometry dependent)} \\
# & i_f &:& \text{armature current} \\
# & i_a &:& \text{armature current} \\
# & K_t &:& \text{torque constant (at a fixed field current, )} & K_t = \phi_f = K_f i_f\\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Mechanical Equation**
#
# $\begin{eqnarray}
# & J \frac{d\omega}{dt} + b\omega + t_L &=& t_{em}\\[0.5em]
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & J &:& \text{total rotation inertia} \\
# & \omega &:& \text{rotor speed} \\
# & t_{em} &:& \text{electromagnetic torque produced by motor} \\
# & b &:& \text{viscous damping coeff} \\
# & t_L &:& \text{load torque} \\
# \end{eqnarray}$

# %% [markdown]
# **Steady State Operation with Constant Flux**
#
# $\begin{eqnarray}
# & i_f &=& I_F \\
# & i_a &=& I_a \\
# & \omega &=& \text{constant} \\
# & V_f &=& R_f I_f \\
# & V_a &=& R_a I_a + E_a \\
# & T_{em} &=& K_t I_a \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Speed-Torque Characteristics**
#
# Given:<br>
# $\begin{eqnarray}
# & e_a &=& E_a \\
# & v_a &=& V_a \\
# & \phi_f &=& \text{constant} \\
# & K_e = K_t &=& \text{constant} \\
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \omega_{NL} &=& \frac{E_a}{K_e} &=& \frac{V_a - I_a R_a}{K_e}\Bigg|_{I_a = t_{em}/K_t} &=& \frac{V_a}{K_e}-\frac{R_a}{K_e K_t}t_{em} & \text{[Speed rad/sec]} \\[0.5em]
# & t_{em} &=& K_t I_a &=& K_t \frac{V_a-E_a}{R_a} &=& \frac{K_t}{R_a}V_a - \frac{K_e K_t}{R_a}\omega_{NL} & \text{[Torque }N\cdot m\text{]} \\[0.5em]
# \end{eqnarray}$
#
# Motor Constant $K_m$  $[\frac{\text{Torque}}{\sqrt{\text{Watt}}}]$
#
# $\begin{eqnarray}
# & K_m^2 &=& \frac{K_e K_t}{R_a} &=& \frac{K_e K_t}{R_a}\frac{I_a^2}{I_a^2} &=& \frac{T_{em}^2}{P_{\text{LOSS}}} \\[0.5em]
# & K_m &=& \frac{T_{em}}{\sqrt{P_{\text{LOSS}}}}
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \text{slope} &=& \frac{-R_a}{K_e K_t} &=& \frac{-1}{K_m^2}
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Series Wound DC Motor**
#
# (Steady State)
#
# $\begin{eqnarray}
# & T_{SS}(\omega) &\propto& \frac{V_a^2}{\omega^2} \\
# & T_{SS}(\omega) &=& \frac{K_f V_a^2}{(R_a+R_f+K_f \omega)^2} \\[0.5em]
# & E_a &=& K_e \omega = I K_f \omega \\[0.5em]
# & V_{SS} &=& (R_a + R_f)I + E_a &=& (R_a + R_f)I + I K_f \omega \\[0.5em]
# & I &=& \frac{V_{SS}}{R_a + R_f + K_f \omega} \\[0.5em]
# & T_{em} &=& K_t I = K_f I^2 \\[0.5em]
# & &=& \frac{V_{SS}^2}{(R_a + R_f + K_f \omega)^2}
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Dynamics**
#
# Laplace: $\frac{d}{dt} \rightarrow p$ <br>
#
# $\begin{align}
#   \begin{array}{ll}
#   \text{Equation} & \text{Time Domain Representation} & \text{LaPlace Domain Representation} \\[0.5em]
#   \text{Armature} & v_a(t) = R_a i_a(t) + L_a \frac{di_a(t)}{dt} + e_a(t) & V_a(p) = R_a I_a(p) + L_a I_a(p)p  + E_a(p) \\[0.5em]
#   \text{Field} & v_f(t) = R_f i_f(t) + L_f \frac{di_f(t)}{dt} & V_f(p) = R_f I_f(p) + L_f  I_f(p)p \\[0.5em]
#   \text{Mechanical} & J\frac{d\omega(t)}{dt} + b\omega(t) + t_L(t) = t_{em}(t) & J\Omega(p)p + b\Omega(p) + T_L(p) = T_{em}(p)
#   \end{array}
# \end{align}$

# %% [markdown]
# **Dynamic Model**
#
# <img src="images/BlockDiagramDCMotor.png" width="500"/>

# %% [markdown]
# $\begin{eqnarray}
# & \Omega &=& \frac{K_t}{JL_a  p^2 + (L_a b + JR_a)p + K_e K_t + bR_a}V_a - \frac{L_a p + R_a}{JL_a p^2 + (L_a b + JR_a)p + K_e K_t + bR_a}T_L \\[0.5em]
# & \frac{\Omega}{V_a} &=& \frac{K_t}{JL_a  p^2 + (L_a b + JR_a)p + K_e K_t + bR_a} \text{ [speed/voltage]}\\[0.5em]
# & \frac{\Omega}{T_L} &=& \frac{L_a p + R_a}{JL_a p^2 + (L_a b + JR_a)p + K_e K_t + bR_a} \text{ [speed/load]}\\[0.5em]
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \text{Let} \\
# && K &=& K_e = K_t \\
# && b &=& 0 &\text{ [viscous damping]} \\
# & \text{Then}
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \frac{\Omega}{V_a} &=& \frac{\frac{K}{JR_a}}{p^2+\frac{R_a}{L_a}p+ \frac{K^2}{JL_a}} \\[0.5em]
# & &=& \frac{\frac{K}{JR_a}}{p^2+\frac{1}{\tau_e}p+ \frac{1}{\tau_m \tau_e}} \text{ [speed/voltage]} \\[0.5em]
# & \tau_e &=& \frac{L_a}{R_a} \text{ electrical time constant} \\[0.5em]
# & \tau_m &=& \frac{JR_a}{K^2} \text{ equivalent electromechanical time constant if electrical transients are very fast}
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Continuing**
#
# $\begin{eqnarray}
# & \text{If} \\
# && L_a &=& 0 \text{ [armature inductance]} \\
# & \text{Then}
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \frac{\Omega}{V_a} &=& \frac{\frac{K}{JR_a}}{p+\frac{K^2}{JR_a}}  \\[0.5em]
# & &=& \frac{\frac{1}{K}\frac{R_a}{L_a}\frac{K^2}{JR_a}}{p^2+\frac{1}{\tau_e}p+ \frac{1}{\tau_m \tau_e}} \\[0.5em]
# & &=& \frac{\frac{1}{K \tau_m \tau_e}}{p^2+\frac{1}{\tau_e}p+ \frac{1}{\tau_m \tau_e}} \text{ [speed/voltage]} \\
# \end{eqnarray}$
#
# <hr>

# %% [markdown]
# **Roots**
#
# $\begin{eqnarray}
# & p &=& -\frac{1}{2\tau_e} \pm \sqrt{\frac{1}{4\tau_e^2}-\frac{1}{\tau_e \tau_m}} \\[0.5em]
# & &=& -\frac{1}{2\tau_e} \pm \frac{1}{\tau_e} \sqrt{\frac{1}{4}-\frac{\tau_e}{\tau_m}} \\[0.5em]
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \text{real roots:} && \frac{\tau_e}{\tau_m} \leq \frac{1}{4} &\rightarrow& \tau_e \leq \frac{1}{4}\tau_m \\[0.5em]
# & \text{complex roots:} && \frac{\tau_e}{\tau_m} \geq \frac{1}{4} &\rightarrow& \tau_e \geq \frac{1}{4}\tau_m \\[0.5em]
# \end{eqnarray}$
#
# <hr>

# %%
# Imports
import sympy as sp
import numpy as np
import pandas as pd
import control
from scipy import signal
from scipy import linalg
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option("display.max_rows", 101)
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline

# Constants
Vf = 360
radsec2rpm = 30/np.pi

# %% [markdown]
# #### 1W Motor

# %%
# 1W Motor
Va1 = 170
If1 = 0.52
Rf1 = Vf/If1
Lf1 = 0.15
Ra1 = 5.59
La1 = 15.5e-3
wn1 = 1300*np.pi/30
Tr1 = 7.0
J1= 3.2e-3
b1 = 1e-4
Ke1 = Va1/wn1
Kf1 = Ke1/If1
Kt1 = Kf1*If1
K = Ke1
TauE = La1/Ra1
TauM = J1*Ra1/(K**2)
TauE, TauM
Ra1/(Ke1*Kt1)
# Out:
# (0.002772808586762075, 0.011471174439065748)
# 3.584742012208046

# %%
# Roots Scypi
# Include damping and armature inductance!
num1 = [K]
den1 = [J1*La1, La1*b1+J1*Ra1, K**2+b1*Ra1]
tf1 = signal.TransferFunction(num1, den1)
tf1.poles

# Without damping and armature inductance
# simple model
num1_s = [1/(K*TauE*TauM)]
den1_s = [1, (1/TauE), 1/(TauE*TauM)]
tf1_s = signal.TransferFunction(num1_s, den1_s)
tf1_s.poles
# Out:
# array([-213.06960861, -147.60680268])
# array([-213.13994764, -147.50521365])

# %%
# Step: Scypi
fig,ax = plt.subplots(1)

T = np.linspace(0,0.25,1000)
t1, y1 = signal.step2(tf1,T=T)
plt.plot(t1, y1)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Speed')
ax.set_title(r'$\frac{\Omega}{V_a}$ Step Response: 1W Motor')
plt.grid(True)
plt.show();

# %% [markdown]
# #### 90.8 W Motor

# %%
# 90.8W Motor
Va91 = 460
If91 = 3.5
Rf91 = Vf/If91
Lf91 = 0.015
Ra91 = 0.09
La91 = 1.0e-3
wn91 = 3000*np.pi/30
Tr91 = 289
J91= 0.2452
b91 = 1e-3
Ke91 = Va91/wn91
Kf91 = Ke91/If91
Kt91 = Kf91*If91
K = Ke91

Ra91/(Ke91*Kt91)
# Out:
# 0.04197846862467119

# %%
# Roots Scypi
# Include damping and armature inductance!

num91 = [K]
den91 = [J91*La91, La91*b91+J91*Ra91, K**2+b91*Ra91]
tf91 = signal.TransferFunction(num91, den91)
tf91.poles
# Out:
# array([-45.00203915+81.96882103j, -45.00203915-81.96882103j])

# %%
# Step: Scypi
fig,ax = plt.subplots(1)

T = np.linspace(0,0.25,1000)
t91, y91 = signal.step2(tf91,T=T)
plt.plot(t91, y91)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Speed')
ax.set_title(r'$\frac{\Omega}{V_a}$ Step Response: 1W Motor')
plt.grid(True)
plt.show();

# %%
# Plot Results in 1 Graph
fig,axs = plt.subplots(2,2, figsize=(12,12))

axs[0, 0].scatter(np.real(tf1.poles),np.imag(tf1.poles),marker='x')
axs[0, 0].set_xlim(-250, 0)
axs[0, 0].set_ylim(50, -50)
axs[0, 0].set_title('1W Motor Eigenvalues')
axs[0, 0].set(xlabel='$\operatorname{Re}(z)$', ylabel='$\operatorname{Im}(z)$')

axs[0, 1].plot(t1, y1*170*30/np.pi)
axs[0, 1].set_title('1W Motor Step Response (V=170)')
axs[0, 1].set(xlabel='Time(s)', ylabel=r'Speed (rpm)')

axs[1, 0].scatter(np.real(tf91.poles),np.imag(tf91.poles),marker='x',color='tab:orange')
axs[1, 0].set_xlim(-50, 0)
axs[1, 0].set_ylim(100, -100)
axs[1, 0].set_title('90.8W Motor Eigenvalues')
axs[1, 0].set(xlabel='$\operatorname{Re}(z)$', ylabel='$\operatorname{Im}(z)$')

axs[1, 1].plot(t91, y91*460*30/np.pi,color='tab:orange')
axs[1, 1].set_title('90.8W Motor Step Response (V=460)')
axs[1, 1].set(xlabel='Time(s)', ylabel=r'Speed (rpm)')

for ax in axs.flat:
    ax.grid(True)
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
#    ax.label_outer()

plt.show();

# %% [markdown]
# #### Speed Torque

# %% [markdown]
# Given:<br>
# $\begin{eqnarray}
# & e_a &=& E_a \\
# & v_a &=& V_a \\
# & \phi_f &=& \text{constant} \\
# & K_e = K_t &=& \text{constant} \\
# \end{eqnarray}$
#
# $\begin{eqnarray}
# & \omega_{NL} &=& \frac{E_a}{K_e} &=& \frac{V_a - I_a R_a}{K_e}\Bigg|_{I_a = t_{em}/K_t} &=& \frac{V_a}{K_e}-\frac{R_a}{K_e K_t}t_{em} & \text{[Speed rad/sec]} \\[0.5em]
# & t_{em} &=& K_t I_a &=& K_t \frac{V_a-E_a}{R_a} &=& \frac{K_t}{R_a}V_a - \frac{K_e K_t}{R_a}\omega_{NL} & \text{[Torque }N\cdot m\text{]} \\[0.5em]
# \end{eqnarray}$

# %%
# Find stall values
T = sp.symbols('T')
sol = sp.solve(sp.Matrix([(Va1/Ke1) - (Ra1/(Ke1*Kt1))*T]))
n1 = float(list(dict(sol).values())[0])
sol = sp.solve(sp.Matrix([(Va91/Ke91) - (Ra91/(Ke91*Kt91))*T]))
n91 = float(list(dict(sol).values())[0])

# Speed Torque Equations
speed_radsec1 = lambda T: (Va1/Ke1) - (Ra1/(Ke1*Kt1))*T
speed_radsec91 = lambda T: (Va91/Ke91) - (Ra91/(Ke91*Kt91))*T

# %%
y0 = speed_radsec1(0)*radsec2rpm
label0 = f"(0, {round(y0,2)})"
y1 = speed_radsec1(n1)*radsec2rpm
label1 = f"({round(n1,2)}, {abs(round(y1,2))})"
y2 = speed_radsec91(0)*radsec2rpm
label2 = f"(0, {round(y2,2)})"
y3 = speed_radsec91(n91)*radsec2rpm
label3 = f"({round(n91,2)}, {round(y3,2)})"

# %%
fig,axs = plt.subplots(2,1,figsize=(10,10))
T1 = np.linspace(0,n1,100)
T91 = np.linspace(0,n91,100)

axs[0].plot(T1,speed_radsec1(T1)*radsec2rpm)
axs[0].scatter(0,y0,label=label0,color='tab:blue')
axs[0].scatter(n1,y1,label=label1,color='tab:blue')
#axs[0, 0].set_xlim(-250, 0)
#axs[0, 0].set_ylim(50, -50)
axs[0].set_title('1W Motor Speed Torque')
axs[0].set(xlabel=r'Torque (N $\cdot$ m)', ylabel=r'Speed (rpm)')

axs[1].plot(T91,speed_radsec91(T91)*radsec2rpm,color='tab:orange')
axs[1].scatter(0,y2,label=label2,color='tab:orange')
axs[1].scatter(n91,y3,label=label3,color='tab:orange')
#axs[1].set_xlim(-50, 0)
#axs[1].set_ylim(100, -100)
axs[1].set_title('90.8W Motor Speed Torque')
axs[1].set(xlabel=r'Torque (N $\cdot$ m)', ylabel=r'Speed (rpm)')

for ax in axs.flat:
    ax.grid(True)
    ax.legend()
plt.show();

# %% [markdown]
# #### Simulation

# %%
lc1_small= pd.read_csv('data/data_loadcase1_small.csv',dtype=np.float64)
lc1_small= lc1_small[lc1_small['Time']<0.25]

lc1_large= pd.read_csv('data/data_loadcase1_large.csv',dtype=np.float64)
lc1_large= lc1_large[lc1_large['Time']<0.25]

lc2_small= pd.read_csv('data/data_loadcase2_small.csv',dtype=np.float64)
lc2_small= lc2_small[lc2_small['Time']<0.25]

lc2_large= pd.read_csv('data/data_loadcase2_large.csv',dtype=np.float64)
lc2_large= lc2_large[lc2_large['Time']<0.25]

lc1_small_sw= pd.read_csv('data/data_loadcase1_small_switching.csv',dtype=np.float64)
lc1_small_sw= lc1_small_sw[lc1_small_sw['Time']<0.25]

lc1_large_sw= pd.read_csv('data/data_loadcase1_large_switching.csv',dtype=np.float64)
lc1_large_sw= lc1_large_sw[lc1_large_sw['Time']<0.25]

lc2_small_sw= pd.read_csv('data/data_loadcase2_small_switching.csv',dtype=np.float64)
lc2_small_sw= lc2_small_sw[lc2_small_sw['Time']<0.25]

lc2_large_sw= pd.read_csv('data/data_loadcase2_large_switching.csv',dtype=np.float64)
lc2_large_sw= lc2_large_sw[lc2_large_sw['Time']<0.25]

lc2_small_sw_1000= pd.read_csv('data/data_loadcase2_small_switching_1000.csv',dtype=np.float64)
lc2_small_sw_1000= lc2_small_sw_1000[lc2_small_sw_1000['Time']<0.25]

lc2_large_sw_1000= pd.read_csv('data/data_loadcase2_large_switching_1000.csv',dtype=np.float64)
lc2_large_sw_1000= lc2_large_sw_1000[lc2_large_sw_1000['Time']<0.25]

# %%
lc1_small_sw.head()
lc2_large_sw.head()
# Out:
#        Time  DC Machine:Armature current  DC Machine:Field current  \
# 0  0.000000                     0.000000                      0.52
# 1  0.000001                     0.043863                      0.52
# 2  0.000009                     0.394199                      0.52
# 3  0.000012                     0.547153                      0.52
# 4  0.000013                     0.547153                      0.52
#
#    DC Machine:Rotational speed  DC Machine:Rotor position  \
# 0                     0.000000               0.000000e+00
# 1                    -0.000023              -1.277192e-11
# 2                     0.000411               8.127702e-10
# 3                     0.000945               3.125240e-09
# 4                     0.000945               3.125240e-09
#
#    DC Machine:Electrical torque  Vm1:Measured voltage
# 0                      0.000000                 680.0
# 1                      0.054774                 680.0
# ...

# %%
# Plot Results in 1 Graph
fig,axs = plt.subplots(3,2, figsize=(12,16))

# Subplot 0 (Armature current)
axs[0, 0].plot(lc1_small['Time'],lc1_small['DC Machine:Armature current'],
               label='0.1 Nm; Ideal Vs',color='tab:blue')

axs[0, 0].plot(lc1_small_sw['Time'],lc1_small_sw['DC Machine:Armature current'],
               label='0.1 Nm; Switching',alpha=.2,color='tab:blue')

axs[0, 0].plot(lc2_small['Time'],lc2_small['DC Machine:Armature current'],
               label='7.0 Nm; Ideal Vs',color='tab:orange')

axs[0, 0].plot(lc2_small_sw['Time'],lc2_small_sw['DC Machine:Armature current'],
               label='7.0 Nm; Switching',alpha=.2,color='tab:orange')

axs[0, 0].set_title('1W Motor Armature Current (A)')
axs[0, 0].set(ylabel='Current (A)')


# Subplot 1 (Armature current)
axs[0, 1].plot(lc1_large['Time'],lc1_large['DC Machine1:Armature current'],
               label='1.0 Nm; Ideal Vs',color='tab:blue')

axs[0, 1].plot(lc1_large_sw['Time'],lc1_large_sw['DC Machine1:Armature current'],
               label='1.0 Nm; Switching',color='tab:blue',linewidth=8,alpha=0.2)

axs[0, 1].plot(lc2_large['Time'],lc2_large['DC Machine1:Armature current'],
               label='300 Nm; Ideal Vs',color='tab:orange')

axs[0, 1].plot(lc2_large_sw['Time'],lc2_large_sw['DC Machine1:Armature current'],
               label='300 Nm; Switching',color='tab:orange',linewidth=8,alpha=0.2)

axs[0, 1].set_title('90.8W Motor Armature Current (A)')
axs[0, 1].set(ylabel='Current (A)')


# Subplot 2 (Rotational speed)
axs[1, 0].plot(lc1_small['Time'],lc1_small['DC Machine:Rotational speed']*radsec2rpm,
               label='0.1 Nm; Ideal Vs',color='tab:blue')

axs[1, 0].plot(lc1_small_sw['Time'],lc1_small_sw['DC Machine:Rotational speed']*radsec2rpm,
               label='0.1 Nm; Switching',color='tab:blue',linewidth=8,alpha=0.2)

axs[1, 0].plot(lc2_small['Time'],lc2_small['DC Machine:Rotational speed']*radsec2rpm,
               label='7.0 Nm; Ideal Vs',color='tab:orange')

axs[1, 0].plot(lc2_small_sw['Time'],lc2_small_sw['DC Machine:Rotational speed']*radsec2rpm,
               label='7.0 Nm; Switching',color='tab:orange',linewidth=8,alpha=0.2)

axs[1, 0].set_title('1W Motor Speed $\omega$ (rpm)')
axs[1, 0].set(ylabel='Speed (rpm)')


# Subplot 3 (Rotational speed)
axs[1, 1].plot(lc1_large['Time'],lc1_large['DC Machine1:Rotational speed']*radsec2rpm,
               label='1.0 Nm; Ideal Vs',color='tab:blue')

axs[1, 1].plot(lc1_large_sw['Time'],lc1_large_sw['DC Machine1:Rotational speed']*radsec2rpm,
               label='1.0 Nm; Switching',color='tab:blue',linewidth=8,alpha=0.2)

axs[1, 1].plot(lc2_large['Time'],lc2_large['DC Machine1:Rotational speed']*radsec2rpm,
               label='300 Nm; Ideal Vs',color='tab:orange')

axs[1, 1].plot(lc2_large_sw['Time'],lc2_large_sw['DC Machine1:Rotational speed']*radsec2rpm,
               label='300 Nm; Switching',color='tab:orange',linewidth=8,alpha=0.2)

axs[1, 1].set_title('90.8W Motor Speed $\omega$ (rpm)')
axs[1, 1].set(ylabel='Speed (rpm)')


# Subplot 4 (Electrical torque)
axs[2, 0].plot(lc1_small['Time'],lc1_small['DC Machine:Electrical torque'],
               label='0.1 Nm; Ideal Vs',color='tab:blue')

axs[2, 0].plot(lc1_small_sw['Time'],lc1_small_sw['DC Machine:Electrical torque'],
               label='0.1 Nm; Switching',color='tab:blue',alpha=0.2)

axs[2, 0].plot(lc2_small['Time'],lc2_small['DC Machine:Electrical torque'],
               label='7.0 Nm; Ideal Vs',color='tab:orange')

axs[2, 0].plot(lc2_small_sw['Time'],lc2_small_sw['DC Machine:Electrical torque'],
               label='7.0 Nm; Switching',color='tab:orange',alpha=0.2)

axs[2, 0].set_title(r'1W Motor Electrical Torque (N $\cdot$ m)')
axs[2, 0].set(ylabel=r'Torque (N $\cdot$ m)',xlabel='Time (s)')


# Subplot 5 (Electrical torque)
axs[2, 1].plot(lc1_large['Time'],lc1_large['DC Machine1:Electrical torque'],
               label='1.0 Nm; Ideal Vs',color='tab:blue')

axs[2, 1].plot(lc1_large_sw['Time'],lc1_large_sw['DC Machine1:Electrical torque'],
               label='1.0 Nm; Switching',color='tab:blue',linewidth=8,alpha=0.2)

axs[2, 1].plot(lc2_large['Time'],lc2_large['DC Machine1:Electrical torque'],
               label='300 Nm; Ideal Vs',color='tab:orange')

axs[2, 1].plot(lc2_large_sw['Time'],lc2_large_sw['DC Machine1:Electrical torque'],
               label='300 Nm; Switching',color='tab:orange',linewidth=8,alpha=0.2)

axs[2, 1].set_title(r'90.8W Motor Electrical Torque (N $\cdot$ m)')
axs[2, 1].set(ylabel=r'Torque (N $\cdot$ m)',xlabel='Time (s)')


for ax in axs.flat:
    ax.grid(True)
    ax.legend()
    #for lh in ax.legend().legendHandles: 
    #    lh.set_alpha(1)
        
plt.show();

# %%
# Plot Results in 1 Graph
fig,axs = plt.subplots(3,2, figsize=(12,16))

# Subplot 0 (Armature current)
axs[0, 0].plot(lc2_small_sw_1000['Time'],lc2_small_sw_1000['DC Machine:Armature current'],
               label='7.0 Nm; 1kHz freq',color='tab:orange')

axs[0, 0].plot(lc2_small_sw['Time'],lc2_small_sw['DC Machine:Armature current'],
               label='7.0 Nm; 20kHz freq',color='tab:blue')

axs[0, 0].set_title('1W Motor Armature Current (A)')
axs[0, 0].set(ylabel='Current (A)')


# Subplot 1 (Armature current)
axs[0, 1].plot(lc2_large_sw_1000['Time'],lc2_large_sw_1000['DC Machine1:Armature current'],
               label='300 Nm; 1kHz freq',color='tab:orange')

axs[0, 1].plot(lc2_large_sw['Time'],lc2_large_sw['DC Machine1:Armature current'],
               label='300 Nm; 20kHz freq',color='tab:blue')

axs[0, 1].set_title('90.8W Motor Armature Current (A)')
axs[0, 1].set(ylabel='Current (A)')


# Subplot 2 (Rotational speed)
axs[1, 0].plot(lc2_small_sw_1000['Time'],lc2_small_sw_1000['DC Machine:Rotational speed']*radsec2rpm,
               label='7.0 Nm; 1kHz freq',color='tab:orange')

axs[1, 0].plot(lc2_small_sw['Time'],lc2_small_sw['DC Machine:Rotational speed']*radsec2rpm,
               label='7.0 Nm; 20kHz freq',color='tab:blue')

axs[1, 0].set_title('1W Motor Speed $\omega$ (rpm)')
axs[1, 0].set(ylabel='Speed (rpm)')


# Subplot 3 (Rotational speed)
axs[1, 1].plot(lc2_large_sw['Time'],lc2_large_sw['DC Machine1:Rotational speed']*radsec2rpm,
               label='300 Nm; 20kHz freq',color='tab:blue')

axs[1, 1].plot(lc2_large_sw_1000['Time'],lc2_large_sw_1000['DC Machine1:Rotational speed']*radsec2rpm,
               label='300 Nm; 1kHz freq',color='tab:orange')

axs[1, 1].set_title('90.8W Motor Speed $\omega$ (rpm)')
axs[1, 1].set(ylabel='Speed (rpm)')


# Subplot 4 (Electrical torque)
axs[2, 0].plot(lc2_small_sw_1000['Time'],lc2_small_sw_1000['DC Machine:Electrical torque'],
               label='7.0 Nm; 1kHz freq',color='tab:orange')

axs[2, 0].plot(lc2_small_sw['Time'],lc2_small_sw['DC Machine:Electrical torque'],
               label='7.0 Nm; 20kHz freq',color='tab:blue')

axs[2, 0].set_title(r'1W Motor Electrical Torque (N $\cdot$ m)')
axs[2, 0].set(ylabel=r'Torque (N $\cdot$ m)',xlabel='Time (s)')


# Subplot 5 (Electrical torque)
axs[2, 1].plot(lc2_large_sw_1000['Time'],lc2_large_sw_1000['DC Machine1:Electrical torque'],
               label='300 Nm; 1kHz freq',color='tab:orange')

axs[2, 1].plot(lc2_large_sw['Time'],lc2_large_sw['DC Machine1:Electrical torque'],
               label='300 Nm; 20kHz freq',color='tab:blue')


axs[2, 1].set_title(r'90.8W Motor Electrical Torque (N $\cdot$ m)')
axs[2, 1].set(ylabel=r'Torque (N $\cdot$ m)',xlabel='Time (s)')


for ax in axs.flat:
    ax.grid(True)
    ax.legend()
    #for lh in ax.legend().legendHandles: 
    #    lh.set_alpha(1)
        
plt.show();

# %% [markdown]
# <hr>
#
# #### Testing
